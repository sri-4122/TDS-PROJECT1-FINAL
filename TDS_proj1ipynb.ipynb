# %%
import requests
import pandas as pd
import time

def make_github_request(url, headers, params=None):
    """Make a GitHub API request with rate limit handling"""
    while True:
        try:
            response = requests.get(url, headers=headers, params=params)
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 403:  # Rate limit exceeded
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                wait_time = max(reset_time - time.time(), 0)
                print(f"Rate limit exceeded. Waiting {wait_time:.0f} seconds...")
                time.sleep(wait_time + 1)
            else:
                print(f"Error {response.status_code}: {response.text}")
                return None
        except Exception as e:
            print(f"Request error: {str(e)}")
            return None

def clean_company_name(company):
    """Clean company names according to specifications"""
    if pd.isna(company) or company is None:
        return ""
    company = str(company).strip()
    if company.startswith('@'):
        company = company[1:]
    return company.upper()

def safe_get(data, *keys, default=''):
    """Safely get nested dictionary values"""
    for key in keys:
        data = data.get(key, None)
        if data is None:
            return default
    return data

def get_github_data():
    """Fetch GitHub data and create CSV files"""
    token = input("Please enter your GitHub token: ").strip()
    if not token:
        print("GitHub token is required.")
        return None, None

    headers = {
        'Authorization': f'token {token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    print("🔍 Searching for users in Hyderabad...")

    users_data = []
    repos_data = []
    search_url = "https://api.github.com/search/users"
    params = {
        'q': 'location:Hyderabad followers:>50',
        'per_page': 100
    }

    page = 1  # Start pagination for user search

    while True:
        params['page'] = page
        search_results = make_github_request(search_url, headers, params)

        if not search_results:
            print("No more results or error encountered in user search.")
            break

        items = search_results.get('items', [])
        if not items:
            break  # No more items to paginate

        print(f"📊 Processing page {page} with {len(items)} users found...")

        for user in items:
            try:
                print(f"\n👤 Fetching data for user: {user.get('login', 'unknown')}")

                # Get user details
                user_data = make_github_request(user['url'], headers)
                if not user_data:
                    print(f"⚠️ Could not fetch details for user {user.get('login', 'unknown')}. Skipping.")
                    continue

                # Append user details to users_data
                users_data.append({
                    'login': safe_get(user_data, 'login'),
                    'name': safe_get(user_data, 'name'),
                    'company': clean_company_name(safe_get(user_data, 'company')),
                    'location': safe_get(user_data, 'location'),
                    'email': safe_get(user_data, 'email'),
                    'hireable': str(safe_get(user_data, 'hireable')).lower(),
                    'bio': safe_get(user_data, 'bio'),
                    'public_repos': safe_get(user_data, 'public_repos', default=0),
                    'followers': safe_get(user_data, 'followers', default=0),
                    'following': safe_get(user_data, 'following', default=0),
                    'created_at': safe_get(user_data, 'created_at')
                })

                # Get repositories
                repos_url = f"https://api.github.com/users/{user['login']}/repos"
                repo_page = 1
                while True:
                    repo_params = {
                        'sort': 'pushed',
                        'direction': 'desc',
                        'per_page': 100,
                        'page': repo_page
                    }
                    repos = make_github_request(repos_url, headers, repo_params)
                    if not repos:
                        print(f"No more repositories for {user.get('login', 'unknown')}.")
                        break

                    for repo in repos:
                        repos_data.append({
                            'login': safe_get(user_data, 'login'),
                            'full_name': safe_get(repo, 'full_name'),
                            'created_at': safe_get(repo, 'created_at'),
                            'stargazers_count': safe_get(repo, 'stargazers_count', default=0),
                            'watchers_count': safe_get(repo, 'watchers_count', default=0),
                            'language': safe_get(repo, 'language'),
                            'has_projects': str(safe_get(repo, 'has_projects')).lower(),
                            'has_wiki': str(safe_get(repo, 'has_wiki')).lower(),
                            'license_name': safe_get(repo, 'license', 'key', default='')
                        })

                    repo_page += 1

            except Exception as e:
                print(f"⚠️ Error processing user {user.get('login', 'unknown')}: {str(e)}")

        # Proceed to the next page for users
        page += 1

    if not users_data:
        print("❌ No user data collected.")
        return None, None

    if not repos_data:
        print("❌ No repository data collected.")
        return None, None

    print(f"\n💾 Creating CSV files for {len(users_data)} users and {len(repos_data)} repositories...")

    # Create DataFrames and save to CSV
    users_df = pd.DataFrame(users_data)
    repos_df = pd.DataFrame(repos_data)
    users_df.to_csv('/content/users.csv', index=False)
    repos_df.to_csv('/content/repositories.csv', index=False)

    return users_df, repos_df

def create_readme(users_df, repos_df):
    """Generate README.md with analysis"""
    print("📝 Generating README.md...")

    try:
        total_users = len(users_df)
        total_repos = len(repos_df)
        avg_followers = users_df['followers'].mean()
        top_languages = repos_df['language'].value_counts().head()
        companies = users_df['company'].value_counts().head()

        total_repos_with_language = len(repos_df[repos_df['language'].notna()])
        python_repos = len(repos_df[repos_df['language'] == 'Python'])
        js_repos = len(repos_df[repos_df['language'] == 'JavaScript'])

        python_percent = (python_repos / total_repos_with_language * 100) if total_repos_with_language > 0 else 0
        js_percent = (js_repos / total_repos_with_language * 100) if total_repos_with_language > 0 else 0
        wiki_percent = (len(repos_df[repos_df['has_wiki'] == 'false']) / len(repos_df) * 100) if len(repos_df) > 0 else 0
        license_percent = (len(repos_df[repos_df['license_name'] == '']) / len(repos_df) * 100) if len(repos_df) > 0 else 0

        readme_content = f"""# GitHub Users Analysis - Hyderabad

* Data was collected using GitHub's REST API v3, focusing on Hyderabad-based developers with 50+ followers, analyzing their profiles and recent repositories with rate limiting and error handling.

* Analysis reveals that Python is the dominant language choice among Hyderabad's top developers, with {python_percent:.1f}% of repositories using it, followed by JavaScript at {js_percent:.1f}% .

* Developers should focus on better documentation and licensing - {wiki_percent:.1f}% of repositories lack wikis and {license_percent:.1f}% lack explicit licenses, which can limit project adoption and collaboration.

## Analysis Details

### User Statistics
- Total Users Analyzed: {total_users}
- Total Repositories: {total_repos}
- Average Followers per User: {avg_followers:.1f}

### Top Programming Languages

### Most Common Companies
"""

        with open('/content/README.md', 'w') as f:
            f.write(readme_content)

    except Exception as e:
        print(f"⚠️ Error generating README: {str(e)}")
        with open('/content/README.md', 'w') as f:
            f.write("# GitHub Users Analysis\n\nError occurred during analysis.")

def main():
    print("🚀 Starting GitHub Analysis...")
    users_df, repos_df = get_github_data()
    if users_df is not None and repos_df is not None:
        create_readme(users_df, repos_df)
        print("\n✅ Analysis complete! Check users.csv, repositories.csv, and README.md in /content directory.")
    else:
        print("\n❌ Analysis failed!")

if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting GitHub Analysis...
# Please enter your GitHub token: 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
# 🔍 Searching for users in Hyderabad...
# 📊 Processing page 1 with 100 users found...
#
# 👤 Fetching data for user: iam-veeramalla
# No more repositories for iam-veeramalla.
#
# 👤 Fetching data for user: in28minutes
# No more repositories for in28minutes.
#
# 👤 Fetching data for user: stacksimplify
# No more repositories for stacksimplify.
#
# 👤 Fetching data for user: thenaveensaggam
# No more repositories for thenaveensaggam.
#
# 👤 Fetching data for user: MadhavBahl
# No more repositories for MadhavBahl.
#
# 👤 Fetching data for user: sivaprasadreddy
# No more repositories for sivaprasadreddy.
#
# 👤 Fetching data for user: ashokitschool
# No more repositories for ashokitschool.
#
# 👤 Fetching data for user: Shahzaib-D-Memon
# No more repositories for Shahzaib-D-Memon.
#
# 👤 Fetching data for user: codewithdev
# No more repositories for codewithdev.
#
# 👤 Fetching data for user: NotHarshhaa
# No more repositories for NotHarshhaa.
#
# 👤 Fetching data for user: InterviewReady
# No more repositories for InterviewReady.
#
# 👤 Fetching data for user: arvindr21
# No more repositories for arvindr21.
#
# 👤 Fetching data for user: javabyraghu
# No more repositories for javabyraghu.
#
# 👤 Fetching data for user: SajeedAI
# No more repositories for SajeedAI.
#
# 👤 Fetching data for user: archygupta
# No more repositories for archygupta.
#
# 👤 Fetching data for user: daminisatya
# No more repositories for daminisatya.
#
# 👤 Fetching data for user: hindupuravinash
# No more repositories for hindupuravinash.
#
# 👤 Fetching data for user: janakiramm
# No more repositories for janakiramm.
#
# 👤 Fetching data for user: erilyth
# No more repositories for erilyth.
#
# 👤 Fetching data for user: imbhargav5
# No more repositories for imbhargav5.
#
# 👤 Fetching data for user: Shra1V32
# No more repositories for Shra1V32.
#
# 👤 Fetching data for user: sriramalavalapati3
# No more repositories for sriramalavalapati3.
#
# 👤 Fetching data for user: algorithmica-repository
# No more repositories for algorithmica-repository.
#
# 👤 Fetching data for user: Rudrabha
# No more repositories for Rudrabha.
#
# 👤 Fetching data for user: aadhar54
# No more repositories for aadhar54.
#
# 👤 Fetching data for user: syedzada1100
# No more repositories for syedzada1100.
#
# 👤 Fetching data for user: mdashrafali-cs
# No more repositories for mdashrafali-cs.
#
# 👤 Fetching data for user: ramsrigouthamg
# No more repositories for ramsrigouthamg.
#
# 👤 Fetching data for user: sitaramc
# No more repositories for sitaramc.
#
# 👤 Fetching data for user: CodeBustler
# No more repositories for CodeBustler.
#
# 👤 Fetching data for user: grvsharma1994
# No more repositories for grvsharma1994.
#
# 👤 Fetching data for user: anoopkunchukuttan
# No more repositories for anoopkunchukuttan.
#
# 👤 Fetching data for user: arbazkiraak
# No more repositories for arbazkiraak.
#
# 👤 Fetching data for user: pavanpodila
# No more repositories for pavanpodila.
#
# 👤 Fetching data for user: durgaprasadUI
# No more repositories for durgaprasadUI.
#
# 👤 Fetching data for user: ASHWIN990
# No more repositories for ASHWIN990.
#
# 👤 Fetching data for user: prituyadav
# No more repositories for prituyadav.
#
# 👤 Fetching data for user: ravi2krishna
# No more repositories for ravi2krishna.
#
# 👤 Fetching data for user: Mirzaazmath
# No more repositories for Mirzaazmath.
#
# 👤 Fetching data for user: saikiranpi
# No more repositories for saikiranpi.
#
# 👤 Fetching data for user: Prince-Shivaram
# No more repositories for Prince-Shivaram.
#
# 👤 Fetching data for user: lerndevops
# No more repositories for lerndevops.
#
# 👤 Fetching data for user: KodiMadhavaRao
# No more repositories for KodiMadhavaRao.
#
# 👤 Fetching data for user: FazeelUsmani
# No more repositories for FazeelUsmani.
#
# 👤 Fetching data for user: ponnamkarthik
# No more repositories for ponnamkarthik.
#
# 👤 Fetching data for user: 0xKayala
# No more repositories for 0xKayala.
#
# 👤 Fetching data for user: pbteja1998
# No more repositories for pbteja1998.
#
# 👤 Fetching data for user: Garima13a
# No more repositories for Garima13a.
#
# 👤 Fetching data for user: manoharreddyporeddy
# No more repositories for manoharreddyporeddy.
#
# 👤 Fetching data for user: vishalsingh2972
# No more repositories for vishalsingh2972.
#
# 👤 Fetching data for user: Kabir-Sagiii
# No more repositories for Kabir-Sagiii.
#
# 👤 Fetching data for user: royalpranjal
# No more repositories for royalpranjal.
#
# 👤 Fetching data for user: maddydevgits
# No more repositories for maddydevgits.
#
# 👤 Fetching data for user: akshatnitd
# No more repositories for akshatnitd.
#
# 👤 Fetching data for user: skbly7
# No more repositories for skbly7.
#
# 👤 Fetching data for user: umangahuja1
# No more repositories for umangahuja1.
#
# 👤 Fetching data for user: shubham1810
# No more repositories for shubham1810.
#
# 👤 Fetching data for user: amanovishnu
# No more repositories for amanovishnu.
#
# 👤 Fetching data for user: vishipayyallore
# No more repositories for vishipayyallore.
#
# 👤 Fetching data for user: PAVANINADELLA
# No more repositories for PAVANINADELLA.
#
# 👤 Fetching data for user: afarhan
# No more repositories for afarhan.
#
# 👤 Fetching data for user: uibrains
# No more repositories for uibrains.
#
# 👤 Fetching data for user: MuhammadHassaanArain
# No more repositories for MuhammadHassaanArain.
#
# 👤 Fetching data for user: machinelearning147
# No more repositories for machinelearning147.
#
# 👤 Fetching data for user: mahi1108
# No more repositories for mahi1108.
#
# 👤 Fetching data for user: vivekreddy-k
# No more repositories for vivekreddy-k.
#
# 👤 Fetching data for user: Santosh2740
# No more repositories for Santosh2740.
#
# 👤 Fetching data for user: GauravWalia19
# No more repositories for GauravWalia19.
#
# 👤 Fetching data for user: Pavankunchala
# No more repositories for Pavankunchala.
#
# 👤 Fetching data for user: rajeshwarpatlolla
# No more repositories for rajeshwarpatlolla.
#
# 👤 Fetching data for user: shravankoninti
# No more repositories for shravankoninti.
#
# 👤 Fetching data for user: SAGARSURI
# No more repositories for SAGARSURI.
#
# 👤 Fetching data for user: anudeepsai
# No more repositories for anudeepsai.
#
# 👤 Fetching data for user: devopsyuva
# No more repositories for devopsyuva.
#
# 👤 Fetching data for user: ajmalsiddiqui
# No more repositories for ajmalsiddiqui.
#
# 👤 Fetching data for user: yashrajkakkad
# No more repositories for yashrajkakkad.
#
# 👤 Fetching data for user: sagaragarwal94
# No more repositories for sagaragarwal94.
#
# 👤 Fetching data for user: DivyaChinta
# No more repositories for DivyaChinta.
#
# 👤 Fetching data for user: cmcodes1
# No more repositories for cmcodes1.
#
# 👤 Fetching data for user: twaritwaikar
# No more repositories for twaritwaikar.
#
# 👤 Fetching data for user: vamandeshmukh
# No more repositories for vamandeshmukh.
#
# 👤 Fetching data for user: DevashishPathrabe
# No more repositories for DevashishPathrabe.
#
# 👤 Fetching data for user: apoorva-dave
# No more repositories for apoorva-dave.
#
# 👤 Fetching data for user: bedapudi6788
# No more repositories for bedapudi6788.
#
# 👤 Fetching data for user: mayank2903
# No more repositories for mayank2903.
#
# 👤 Fetching data for user: r-devops
# No more repositories for r-devops.
#
# 👤 Fetching data for user: AmeerAbdul7
# No more repositories for AmeerAbdul7.
#
# 👤 Fetching data for user: Abhey
# No more repositories for Abhey.
#
# 👤 Fetching data for user: pinkeshbadjatiya
# No more repositories for pinkeshbadjatiya.
#
# 👤 Fetching data for user: shabda
# No more repositories for shabda.
#
# 👤 Fetching data for user: NitishGadangi
# No more repositories for NitishGadangi.
#
# 👤 Fetching data for user: manishprivet
# No more repositories for manishprivet.
#
# 👤 Fetching data for user: mujaheed13
# No more repositories for mujaheed13.
#
# 👤 Fetching data for user: saiankit
# No more repositories for saiankit.
#
# 👤 Fetching data for user: sharanya02
# No more repositories for sharanya02.
#
# 👤 Fetching data for user: gkdevops
# No more repositories for gkdevops.
#
# 👤 Fetching data for user: ironmaniiith
# No more repositories for ironmaniiith.
#
# 👤 Fetching data for user: abhishekrawe
# No more repositories for abhishekrawe.
#
# 👤 Fetching data for user: vihar
# No more repositories for vihar.
#
# 👤 Fetching data for user: arnab9593
# No more repositories for arnab9593.
# 📊 Processing page 2 with 100 users found...
#
# 👤 Fetching data for user: nithingooud
# No more repositories for nithingooud.
#
# 👤 Fetching data for user: arunmotoori
# No more repositories for arunmotoori.
#
# 👤 Fetching data for user: swetanjal
# No more repositories for swetanjal.
#
# 👤 Fetching data for user: RahulSonali
# No more repositories for RahulSonali.
#
# 👤 Fetching data for user: mohanbabi
# No more repositories for mohanbabi.
#
# 👤 Fetching data for user: ravikishore1993
# No more repositories for ravikishore1993.
#
# 👤 Fetching data for user: prudhvir3ddy
# No more repositories for prudhvir3ddy.
#
# 👤 Fetching data for user: nischalare
# No more repositories for nischalare.
#
# 👤 Fetching data for user: SaumyaMohandas
# No more repositories for SaumyaMohandas.
#
# 👤 Fetching data for user: vivekvardhan2810
# No more repositories for vivekvardhan2810.
#
# 👤 Fetching data for user: Srikarmk
# No more repositories for Srikarmk.
#
# 👤 Fetching data for user: kaushik-rishi
# No more repositories for kaushik-rishi.
#
# 👤 Fetching data for user: feat7
# No more repositories for feat7.
#
# 👤 Fetching data for user: susiejojo
# No more repositories for susiejojo.
#
# 👤 Fetching data for user: muralikrishna188
# No more repositories for muralikrishna188.
#
# 👤 Fetching data for user: kshyam
# No more repositories for kshyam.
#
# 👤 Fetching data for user: linuxautomations
# No more repositories for linuxautomations.
#
# 👤 Fetching data for user: codelixir
# No more repositories for codelixir.
#
# 👤 Fetching data for user: BadagalaAdarsh
# No more repositories for BadagalaAdarsh.
#
# 👤 Fetching data for user: MayankGoel28
# No more repositories for MayankGoel28.
#
# 👤 Fetching data for user: suhailroushan13
# No more repositories for suhailroushan13.
#
# 👤 Fetching data for user: vishnupriya888
# No more repositories for vishnupriya888.
#
# 👤 Fetching data for user: aravindballa
# No more repositories for aravindballa.
#
# 👤 Fetching data for user: adiralashiva8
# No more repositories for adiralashiva8.
#
# 👤 Fetching data for user: sav98aman
# No more repositories for sav98aman.
#
# 👤 Fetching data for user: zubairabid
# No more repositories for zubairabid.
#
# 👤 Fetching data for user: doltonfernandes
# No more repositories for doltonfernandes.
#
# 👤 Fetching data for user: praveenpuglia
# No more repositories for praveenpuglia.
#
# 👤 Fetching data for user: Shekharrajak
# No more repositories for Shekharrajak.
#
# 👤 Fetching data for user: muskankhedia
# No more repositories for muskankhedia.
#
# 👤 Fetching data for user: jaiakash
# No more repositories for jaiakash.
#
# 👤 Fetching data for user: urvashii-b
# No more repositories for urvashii-b.
#
# 👤 Fetching data for user: aravind-selvam
# No more repositories for aravind-selvam.
#
# 👤 Fetching data for user: NarayandasGanesh
# No more repositories for NarayandasGanesh.
#
# 👤 Fetching data for user: Himanshu12866
# No more repositories for Himanshu12866.
#
# 👤 Fetching data for user: prakashpandey9
# No more repositories for prakashpandey9.
#
# 👤 Fetching data for user: jhansireddy
# No more repositories for jhansireddy.
#
# 👤 Fetching data for user: SwethaVipparla
# No more repositories for SwethaVipparla.
#
# 👤 Fetching data for user: waseem18
# No more repositories for waseem18.
#
# 👤 Fetching data for user: nikhilrayaprolu
# No more repositories for nikhilrayaprolu.
#
# 👤 Fetching data for user: AgamAgarwal
# No more repositories for AgamAgarwal.
#
# 👤 Fetching data for user: Ahish9009
# No more repositories for Ahish9009.
#
# 👤 Fetching data for user: ashwin31
# No more repositories for ashwin31.
#
# 👤 Fetching data for user: abhinav-upadhyay
# No more repositories for abhinav-upadhyay.
#
# 👤 Fetching data for user: asdsyd
# No more repositories for asdsyd.
#
# 👤 Fetching data for user: kaziadilmemon
# No more repositories for kaziadilmemon.
#
# 👤 Fetching data for user: RakeshSangem
# No more repositories for RakeshSangem.
#
# 👤 Fetching data for user: venkynaidu
# No more repositories for venkynaidu.
#
# 👤 Fetching data for user: saurabh618
# No more repositories for saurabh618.
#
# 👤 Fetching data for user: nowitsramesh
# No more repositories for nowitsramesh.
#
# 👤 Fetching data for user: victorknox
# No more repositories for victorknox.
#
# 👤 Fetching data for user: 0xMukesh
# No more repositories for 0xMukesh.
#
# 👤 Fetching data for user: SaikrishnaReddy1919
# No more repositories for SaikrishnaReddy1919.
#
# 👤 Fetching data for user: shankybnl
# No more repositories for shankybnl.
#
# 👤 Fetching data for user: ankits-svg
# No more repositories for ankits-svg.
#
# 👤 Fetching data for user: Pothulapati
# No more repositories for Pothulapati.
#
# 👤 Fetching data for user: sanjushasuresh
# No more repositories for sanjushasuresh.
#
# 👤 Fetching data for user: raipankaj
# No more repositories for raipankaj.
#
# 👤 Fetching data for user: vramana
# No more repositories for vramana.
#
# 👤 Fetching data for user: pranjalchaubey
# No more repositories for pranjalchaubey.
#
# 👤 Fetching data for user: MuhammadZubair786
# No more repositories for MuhammadZubair786.
#
# 👤 Fetching data for user: xrisk
# No more repositories for xrisk.
#
# 👤 Fetching data for user: kumarawsbit
# No more repositories for kumarawsbit.
#
# 👤 Fetching data for user: ScrapCodes
# No more repositories for ScrapCodes.
#
# 👤 Fetching data for user: adnanali-in
# No more repositories for adnanali-in.
#
# 👤 Fetching data for user: anantcodes
# No more repositories for anantcodes.
#
# 👤 Fetching data for user: sonali123123
# No more repositories for sonali123123.
#
# 👤 Fetching data for user: dnabanita7
# No more repositories for dnabanita7.
#
# 👤 Fetching data for user: nickinack
# No more repositories for nickinack.
#
# 👤 Fetching data for user: naveen-uppala
# No more repositories for naveen-uppala.
#
# 👤 Fetching data for user: saichandrareddy1
# No more repositories for saichandrareddy1.
#
# 👤 Fetching data for user: aaryamvn
# No more repositories for aaryamvn.
#
# 👤 Fetching data for user: rajdeepd
# No more repositories for rajdeepd.
#
# 👤 Fetching data for user: ERAMITDHOMNE
# No more repositories for ERAMITDHOMNE.
#
# 👤 Fetching data for user: henit-chobisa
# No more repositories for henit-chobisa.
#
# 👤 Fetching data for user: farida-techie
# No more repositories for farida-techie.
#
# 👤 Fetching data for user: soumitradev
# No more repositories for soumitradev.
#
# 👤 Fetching data for user: zephyrzilla
# No more repositories for zephyrzilla.
#
# 👤 Fetching data for user: chandu078
# No more repositories for chandu078.
#
# 👤 Fetching data for user: kuluruvineeth
# No more repositories for kuluruvineeth.
#
# 👤 Fetching data for user: zjesko
# No more repositories for zjesko.
#
# 👤 Fetching data for user: dkapur17
# No more repositories for dkapur17.
#
# 👤 Fetching data for user: vkosuri
# No more repositories for vkosuri.
#
# 👤 Fetching data for user: kalyanhadooptraining
# No more repositories for kalyanhadooptraining.
#
# 👤 Fetching data for user: mssanamateen
# No more repositories for mssanamateen.
#
# 👤 Fetching data for user: ankitpati
# No more repositories for ankitpati.
#
# 👤 Fetching data for user: prasoonsoni
# No more repositories for prasoonsoni.
#
# 👤 Fetching data for user: anjijava16
# No more repositories for anjijava16.
#
# 👤 Fetching data for user: 07-Mayankraj
# No more repositories for 07-Mayankraj.
#
# 👤 Fetching data for user: ananyaarun
# No more repositories for ananyaarun.
#
# 👤 Fetching data for user: Karthik2917k
# No more repositories for Karthik2917k.
#
# 👤 Fetching data for user: CaptainIRS
# No more repositories for CaptainIRS.
#
# 👤 Fetching data for user: AurumnPegasus
# No more repositories for AurumnPegasus.
#
# 👤 Fetching data for user: Monicabishnoi
# No more repositories for Monicabishnoi.
#
# 👤 Fetching data for user: 0xVikasRushi
# No more repositories for 0xVikasRushi.
#
# 👤 Fetching data for user: akcube
# No more repositories for akcube.
#
# 👤 Fetching data for user: vinaykumar2n
# No more repositories for vinaykumar2n.
#
# 👤 Fetching data for user: coniferousdyer
# No more repositories for coniferousdyer.
#
# 👤 Fetching data for user: tracksdata
# No more repositories for tracksdata.
#
# 👤 Fetching data for user: rajeshThappeta
# No more repositories for rajeshThappeta.
# 📊 Processing page 3 with 100 users found...
#
# 👤 Fetching data for user: UmamaheshMaxwell
# No more repositories for UmamaheshMaxwell.
#
# 👤 Fetching data for user: Parth-Jain-2002
# No more repositories for Parth-Jain-2002.
#
# 👤 Fetching data for user: kolaparthisrini
# No more repositories for kolaparthisrini.
#
# 👤 Fetching data for user: surajbahadur591
# No more repositories for surajbahadur591.
#
# 👤 Fetching data for user: devikumavath
# No more repositories for devikumavath.
#
# 👤 Fetching data for user: ahmedgulabkhan
# No more repositories for ahmedgulabkhan.
#
# 👤 Fetching data for user: shravankumar147
# No more repositories for shravankumar147.
#
# 👤 Fetching data for user: nandakishormpai
# No more repositories for nandakishormpai.
#
# 👤 Fetching data for user: dheerajpreddy
# No more repositories for dheerajpreddy.
#
# 👤 Fetching data for user: shash42
# No more repositories for shash42.
#
# 👤 Fetching data for user: harshita130602
# No more repositories for harshita130602.
#
# 👤 Fetching data for user: inovizz
# No more repositories for inovizz.
#
# 👤 Fetching data for user: phanimahesh
# No more repositories for phanimahesh.
#
# 👤 Fetching data for user: prasunanand
# No more repositories for prasunanand.
#
# 👤 Fetching data for user: Diksha-Rathi
# No more repositories for Diksha-Rathi.
#
# 👤 Fetching data for user: Anjani1598
# No more repositories for Anjani1598.
#
# 👤 Fetching data for user: venkat09docs
# No more repositories for venkat09docs.
#
# 👤 Fetching data for user: shb9019
# No more repositories for shb9019.
#
# 👤 Fetching data for user: crux-bphc
# No more repositories for crux-bphc.
#
# 👤 Fetching data for user: banrovegrie
# No more repositories for banrovegrie.
#
# 👤 Fetching data for user: keshav-exe
# No more repositories for keshav-exe.
#
# 👤 Fetching data for user: mhardik003
# No more repositories for mhardik003.
#
# 👤 Fetching data for user: sravikiran
# No more repositories for sravikiran.
#
# 👤 Fetching data for user: JuiP
# No more repositories for JuiP.
#
# 👤 Fetching data for user: prateekagrawaliiit
# No more repositories for prateekagrawaliiit.
#
# 👤 Fetching data for user: Abdul535
# No more repositories for Abdul535.
#
# 👤 Fetching data for user: iampranavdhar
# No more repositories for iampranavdhar.
#
# 👤 Fetching data for user: dharavathramdas101
# No more repositories for dharavathramdas101.
#
# 👤 Fetching data for user: elevenpassin
# No more repositories for elevenpassin.
#
# 👤 Fetching data for user: chakrihacker
# No more repositories for chakrihacker.
#
# 👤 Fetching data for user: Balu-Varanasi
# No more repositories for Balu-Varanasi.
#
# 👤 Fetching data for user: SimranAnand1
# No more repositories for SimranAnand1.
#
# 👤 Fetching data for user: anishkasachdeva
# No more repositories for anishkasachdeva.
#
# 👤 Fetching data for user: akshatdalton
# No more repositories for akshatdalton.
#
# 👤 Fetching data for user: MicroPyramid
# No more repositories for MicroPyramid.
#
# 👤 Fetching data for user: yaswanthpalaghat
# No more repositories for yaswanthpalaghat.
#
# 👤 Fetching data for user: sshreevignesh
# No more repositories for sshreevignesh.
#
# 👤 Fetching data for user: Ashish-kumar7
# No more repositories for Ashish-kumar7.
#
# 👤 Fetching data for user: tanya-tm
# No more repositories for tanya-tm.
#
# 👤 Fetching data for user: thecaffeinedev
# No more repositories for thecaffeinedev.
#
# 👤 Fetching data for user: tejasvicsr1
# No more repositories for tejasvicsr1.
#
# 👤 Fetching data for user: vibhanshujainiiitr
# No more repositories for vibhanshujainiiitr.
#
# 👤 Fetching data for user: Vikram310
# No more repositories for Vikram310.
#
# 👤 Fetching data for user: Safiakhatoon767
# No more repositories for Safiakhatoon767.
#
# 👤 Fetching data for user: rvk7895
# No more repositories for rvk7895.
#
# 👤 Fetching data for user: codewithshek
# No more repositories for codewithshek.
#
# 👤 Fetching data for user: freyamehta99
# No more repositories for freyamehta99.
#
# 👤 Fetching data for user: owii8247
# No more repositories for owii8247.
#
# 👤 Fetching data for user: AKSHITHA-CHILUKA
# No more repositories for AKSHITHA-CHILUKA.
#
# 👤 Fetching data for user: iamshubhamg
# No more repositories for iamshubhamg.
#
# 👤 Fetching data for user: Mehulcoder
# No more repositories for Mehulcoder.
#
# 👤 Fetching data for user: rajarsheem
# No more repositories for rajarsheem.
#
# 👤 Fetching data for user: theja-m
# No more repositories for theja-m.
#
# 👤 Fetching data for user: arunsridher
# No more repositories for arunsridher.
#
# 👤 Fetching data for user: akshar-raaj
# No more repositories for akshar-raaj.
#
# 👤 Fetching data for user: FleetAdmiral
# No more repositories for FleetAdmiral.
#
# 👤 Fetching data for user: AnupNair08
# No more repositories for AnupNair08.
#
# 👤 Fetching data for user: Prakash2403
# No more repositories for Prakash2403.
#
# 👤 Fetching data for user: ujjwal-raizada
# No more repositories for ujjwal-raizada.
#
# 👤 Fetching data for user: sudhir-voleti
# No more repositories for sudhir-voleti.
#
# 👤 Fetching data for user: wolfram77
# No more repositories for wolfram77.
#
# 👤 Fetching data for user: srikanthlogic
# No more repositories for srikanthlogic.
#
# 👤 Fetching data for user: nmondal
# No more repositories for nmondal.
#
# 👤 Fetching data for user: sushrut111
# No more repositories for sushrut111.
#
# 👤 Fetching data for user: nimitbhardwaj
# No more repositories for nimitbhardwaj.
#
# 👤 Fetching data for user: Vanshika-Rana
# No more repositories for Vanshika-Rana.
#
# 👤 Fetching data for user: callmepandey
# No more repositories for callmepandey.
#
# 👤 Fetching data for user: arpan-dasgupta
# No more repositories for arpan-dasgupta.
#
# 👤 Fetching data for user: KirankumarAmbati
# No more repositories for KirankumarAmbati.
#
# 👤 Fetching data for user: harinadh76
# No more repositories for harinadh76.
#
# 👤 Fetching data for user: mridulnagpal
# No more repositories for mridulnagpal.
#
# 👤 Fetching data for user: JyotimoyKashyap
# No more repositories for JyotimoyKashyap.
#
# 👤 Fetching data for user: virenv
# No more repositories for virenv.
#
# 👤 Fetching data for user: iakhilteja
# No more repositories for iakhilteja.
#
# 👤 Fetching data for user: Vikr-182
# No more repositories for Vikr-182.
#
# 👤 Fetching data for user: Bhavnaharitsa
# No more repositories for Bhavnaharitsa.
#
# 👤 Fetching data for user: ganeshi4u
# No more repositories for ganeshi4u.
#
# 👤 Fetching data for user: SetuCoder
# No more repositories for SetuCoder.
#
# 👤 Fetching data for user: shivensinha4
# No more repositories for shivensinha4.
#
# 👤 Fetching data for user: Anji515
# No more repositories for Anji515.
#
# 👤 Fetching data for user: Gaini-Laxman
# No more repositories for Gaini-Laxman.
#
# 👤 Fetching data for user: kasiriveni
# No more repositories for kasiriveni.
#
# 👤 Fetching data for user: chaitan94
# No more repositories for chaitan94.
#
# 👤 Fetching data for user: ashu12chi
# No more repositories for ashu12chi.
#
# 👤 Fetching data for user: gokulyc
# No more repositories for gokulyc.
#
# 👤 Fetching data for user: srinisbook
# No more repositories for srinisbook.
#
# 👤 Fetching data for user: praveensripati
# No more repositories for praveensripati.
#
# 👤 Fetching data for user: rishabsingh3003
# No more repositories for rishabsingh3003.
#
# 👤 Fetching data for user: rkritika1508
# No more repositories for rkritika1508.
#
# 👤 Fetching data for user: kirankaranth1
# No more repositories for kirankaranth1.
#
# 👤 Fetching data for user: WinterSoldier13
# No more repositories for WinterSoldier13.
#
# 👤 Fetching data for user: jkka777
# No more repositories for jkka777.
#
# 👤 Fetching data for user: divais
# No more repositories for divais.
#
# 👤 Fetching data for user: kansiris
# No more repositories for kansiris.
#
# 👤 Fetching data for user: bandirevanth
# No more repositories for bandirevanth.
#
# 👤 Fetching data for user: whoisandy
# No more repositories for whoisandy.
#
# 👤 Fetching data for user: vanigupta20024
# No more repositories for vanigupta20024.
#
# 👤 Fetching data for user: ananyo2012
# No more repositories for ananyo2012.
#
# 👤 Fetching data for user: purugupta99
# No more repositories for purugupta99.
#
# 👤 Fetching data for user: suneelbvs
# No more repositories for suneelbvs.
# 📊 Processing page 4 with 100 users found...
#
# 👤 Fetching data for user: amul-agrawal
# No more repositories for amul-agrawal.
#
# 👤 Fetching data for user: sirilalithaadapa
# No more repositories for sirilalithaadapa.
#
# 👤 Fetching data for user: bitoffabyte
# No more repositories for bitoffabyte.
#
# 👤 Fetching data for user: srinivaskolaparthi
# No more repositories for srinivaskolaparthi.
#
# 👤 Fetching data for user: BhanuPrathapGoud
# No more repositories for BhanuPrathapGoud.
#
# 👤 Fetching data for user: avijit9
# No more repositories for avijit9.
#
# 👤 Fetching data for user: RaghuVarma331
# No more repositories for RaghuVarma331.
#
# 👤 Fetching data for user: imajaydwivedi
# No more repositories for imajaydwivedi.
#
# 👤 Fetching data for user: harshit3011
# No more repositories for harshit3011.
#
# 👤 Fetching data for user: sriramveeraghanta
# No more repositories for sriramveeraghanta.
#
# 👤 Fetching data for user: axayjha
# No more repositories for axayjha.
#
# 👤 Fetching data for user: Zshan0
# No more repositories for Zshan0.
#
# 👤 Fetching data for user: samhita-alla
# No more repositories for samhita-alla.
#
# 👤 Fetching data for user: saidinesh5
# No more repositories for saidinesh5.
#
# 👤 Fetching data for user: thrilok209
# No more repositories for thrilok209.
#
# 👤 Fetching data for user: Deepali-Shinde
# No more repositories for Deepali-Shinde.
#
# 👤 Fetching data for user: jaggu21
# No more repositories for jaggu21.
#
# 👤 Fetching data for user: DivanshiGupta
# No more repositories for DivanshiGupta.
#
# 👤 Fetching data for user: souvik150
# No more repositories for souvik150.
#
# 👤 Fetching data for user: husain-zaidi
# No more repositories for husain-zaidi.
#
# 👤 Fetching data for user: vaishnaviabbugari
# No more repositories for vaishnaviabbugari.
#
# 👤 Fetching data for user: rajeshkumarkarra
# No more repositories for rajeshkumarkarra.
#
# 👤 Fetching data for user: kartikmandhan
# No more repositories for kartikmandhan.
#
# 👤 Fetching data for user: Naman82
# No more repositories for Naman82.
#
# 👤 Fetching data for user: offensivesecurity
# No more repositories for offensivesecurity.
#
# 👤 Fetching data for user: akshayblevel
# No more repositories for akshayblevel.
#
# 👤 Fetching data for user: sayedrafeeq
# No more repositories for sayedrafeeq.
#
# 👤 Fetching data for user: biswaroop1547
# No more repositories for biswaroop1547.
#
# 👤 Fetching data for user: Sharathchandra345
# No more repositories for Sharathchandra345.
#
# 👤 Fetching data for user: Jsuresh47
# No more repositories for Jsuresh47.
#
# 👤 Fetching data for user: apnerve
# No more repositories for apnerve.
#
# 👤 Fetching data for user: narimetisaigopi
# No more repositories for narimetisaigopi.
#
# 👤 Fetching data for user: shreyamalogi
# No more repositories for shreyamalogi.
#
# 👤 Fetching data for user: Puneet2000
# No more repositories for Puneet2000.
#
# 👤 Fetching data for user: DRA-chaos
# No more repositories for DRA-chaos.
#
# 👤 Fetching data for user: h-sinha
# No more repositories for h-sinha.
#
# 👤 Fetching data for user: tulasiram58827
# No more repositories for tulasiram58827.
#
# 👤 Fetching data for user: Joe2k
# No more repositories for Joe2k.
#
# 👤 Fetching data for user: hemanth22
# No more repositories for hemanth22.
#
# 👤 Fetching data for user: imjohnzakkam
# No more repositories for imjohnzakkam.
#
# 👤 Fetching data for user: prachiagrawal237
# No more repositories for prachiagrawal237.
#
# 👤 Fetching data for user: ayushpateria
# No more repositories for ayushpateria.
#
# 👤 Fetching data for user: tittuvarghese
# No more repositories for tittuvarghese.
#
# 👤 Fetching data for user: bmkmanoj
# No more repositories for bmkmanoj.
#
# 👤 Fetching data for user: specialsusheel
# No more repositories for specialsusheel.
#
# 👤 Fetching data for user: singhalpranav22
# No more repositories for singhalpranav22.
#
# 👤 Fetching data for user: abdullahhassan19
# No more repositories for abdullahhassan19.
#
# 👤 Fetching data for user: sasikiran
# No more repositories for sasikiran.
#
# 👤 Fetching data for user: PrajwalKrishna
# No more repositories for PrajwalKrishna.
#
# 👤 Fetching data for user: praveenr019
# No more repositories for praveenr019.
#
# 👤 Fetching data for user: hacksdump
# No more repositories for hacksdump.
#
# 👤 Fetching data for user: ahmedkaludi
# No more repositories for ahmedkaludi.
#
# 👤 Fetching data for user: harshil93
# No more repositories for harshil93.
#
# 👤 Fetching data for user: azharullah
# No more repositories for azharullah.
#
# 👤 Fetching data for user: crusader2000
# No more repositories for crusader2000.
#
# 👤 Fetching data for user: Sam-Si
# No more repositories for Sam-Si.
#
# 👤 Fetching data for user: Sudhindra3000
# No more repositories for Sudhindra3000.
#
# 👤 Fetching data for user: narasimhavuppala
# No more repositories for narasimhavuppala.
#
# 👤 Fetching data for user: shaadomanthra
# No more repositories for shaadomanthra.
#
# 👤 Fetching data for user: Pranavtechie
# No more repositories for Pranavtechie.
#
# 👤 Fetching data for user: mrc03
# No more repositories for mrc03.
#
# 👤 Fetching data for user: HelioStrike
# No more repositories for HelioStrike.
#
# 👤 Fetching data for user: arijitx
# No more repositories for arijitx.
#
# 👤 Fetching data for user: Lishat
# No more repositories for Lishat.
#
# 👤 Fetching data for user: IITH-Epoch
# No more repositories for IITH-Epoch.
#
# 👤 Fetching data for user: saikrithik
# No more repositories for saikrithik.
#
# 👤 Fetching data for user: Muhammad-Osama-Qureshi
# No more repositories for Muhammad-Osama-Qureshi.
#
# 👤 Fetching data for user: Kush0301
# No more repositories for Kush0301.
#
# 👤 Fetching data for user: mintuhouse
# No more repositories for mintuhouse.
#
# 👤 Fetching data for user: mohanarunachalam
# No more repositories for mohanarunachalam.
#
# 👤 Fetching data for user: VarunT11
# No more repositories for VarunT11.
#
# 👤 Fetching data for user: shivank01
# No more repositories for shivank01.
#
# 👤 Fetching data for user: Rishav-hub
# No more repositories for Rishav-hub.
#
# 👤 Fetching data for user: MRamya-sri
# No more repositories for MRamya-sri.
#
# 👤 Fetching data for user: pavs315
# No more repositories for pavs315.
#
# 👤 Fetching data for user: GO-viper7
# No more repositories for GO-viper7.
#
# 👤 Fetching data for user: chinmaydas96
# No more repositories for chinmaydas96.
#
# 👤 Fetching data for user: shriomtri
# No more repositories for shriomtri.
#
# 👤 Fetching data for user: naman1901
# No more repositories for naman1901.
#
# 👤 Fetching data for user: kritikarag
# No more repositories for kritikarag.
#
# 👤 Fetching data for user: mnadeem
# No more repositories for mnadeem.
#
# 👤 Fetching data for user: Mustaqhasan
# No more repositories for Mustaqhasan.
#
# 👤 Fetching data for user: Ankush96
# No more repositories for Ankush96.
#
# 👤 Fetching data for user: GaneshGanta
# No more repositories for GaneshGanta.
#
# 👤 Fetching data for user: walkingtree
# No more repositories for walkingtree.
#
# 👤 Fetching data for user: amoghakancharla
# No more repositories for amoghakancharla.
#
# 👤 Fetching data for user: The-Coder-Kishor
# No more repositories for The-Coder-Kishor.
#
# 👤 Fetching data for user: samacker77
# No more repositories for samacker77.
#
# 👤 Fetching data for user: saurabhmarpadge
# No more repositories for saurabhmarpadge.
#
# 👤 Fetching data for user: debo98
# No more repositories for debo98.
#
# 👤 Fetching data for user: srimani-programmer
# No more repositories for srimani-programmer.
#
# 👤 Fetching data for user: vikaschoudhary16
# No more repositories for vikaschoudhary16.
#
# 👤 Fetching data for user: Bharathbrothers
# No more repositories for Bharathbrothers.
#
# 👤 Fetching data for user: wahidKhan74
# No more repositories for wahidKhan74.
#
# 👤 Fetching data for user: DevPranjal
# No more repositories for DevPranjal.
#
# 👤 Fetching data for user: snath99920
# No more repositories for snath99920.
#
# 👤 Fetching data for user: MSurfer20
# No more repositories for MSurfer20.
#
# 👤 Fetching data for user: RAJANAGORI
# No more repositories for RAJANAGORI.
#
# 👤 Fetching data for user: avinashkoyyana
# No more repositories for avinashkoyyana.
#
# 👤 Fetching data for user: amit-bhandari
# No more repositories for amit-bhandari.
# 📊 Processing page 5 with 100 users found...
#
# 👤 Fetching data for user: saisandhya3198
# No more repositories for saisandhya3198.
#
# 👤 Fetching data for user: keshakaneria
# No more repositories for keshakaneria.
#
# 👤 Fetching data for user: omkar-334
# No more repositories for omkar-334.
#
# 👤 Fetching data for user: static-var
# No more repositories for static-var.
#
# 👤 Fetching data for user: 20sw084
# No more repositories for 20sw084.
#
# 👤 Fetching data for user: sreesysadm
# No more repositories for sreesysadm.
#
# 👤 Fetching data for user: RoboticsClub-IIITH
# No more repositories for RoboticsClub-IIITH.
#
# 👤 Fetching data for user: arnavsharma93
# No more repositories for arnavsharma93.
#
# 👤 Fetching data for user: malihanan
# No more repositories for malihanan.
#
# 👤 Fetching data for user: arshiya786-af
# No more repositories for arshiya786-af.
#
# 👤 Fetching data for user: rameshkec85
# No more repositories for rameshkec85.
#
# 👤 Fetching data for user: Hanzalashaik
# No more repositories for Hanzalashaik.
#
# 👤 Fetching data for user: rajatmaheshwari2512
# No more repositories for rajatmaheshwari2512.
#
# 👤 Fetching data for user: pratishtha-abrol
# No more repositories for pratishtha-abrol.
#
# 👤 Fetching data for user: psahithireddy
# No more repositories for psahithireddy.
#
# 👤 Fetching data for user: srinibasbiswal
# No more repositories for srinibasbiswal.
#
# 👤 Fetching data for user: sonali9696
# No more repositories for sonali9696.
#
# 👤 Fetching data for user: Deepayan137
# No more repositories for Deepayan137.
#
# 👤 Fetching data for user: AbhijnanVegi
# No more repositories for AbhijnanVegi.
#
# 👤 Fetching data for user: susruth
# No more repositories for susruth.
#
# 👤 Fetching data for user: arhik
# No more repositories for arhik.
#
# 👤 Fetching data for user: suryanshsrivastava
# No more repositories for suryanshsrivastava.
#
# 👤 Fetching data for user: shubham9411
# No more repositories for shubham9411.
#
# 👤 Fetching data for user: anuragnatoo
# No more repositories for anuragnatoo.
#
# 👤 Fetching data for user: Vishal0203
# No more repositories for Vishal0203.
#
# 👤 Fetching data for user: skvrahul
# No more repositories for skvrahul.
#
# 👤 Fetching data for user: Puneeth-hub
# No more repositories for Puneeth-hub.
#
# 👤 Fetching data for user: Zohaib-Sathio
# No more repositories for Zohaib-Sathio.
#
# 👤 Fetching data for user: cryptomint0
# No more repositories for cryptomint0.
#
# 👤 Fetching data for user: PALASH-BAJPAI
# No more repositories for PALASH-BAJPAI.
#
# 👤 Fetching data for user: iraycd
# No more repositories for iraycd.
#
# 👤 Fetching data for user: biju-borah
# No more repositories for biju-borah.
#
# 👤 Fetching data for user: deucaleon18
# No more repositories for deucaleon18.
#
# 👤 Fetching data for user: srikharshashi
# No more repositories for srikharshashi.
#
# 👤 Fetching data for user: fayaz07
# No more repositories for fayaz07.
#
# 👤 Fetching data for user: swaroopnadella
# No more repositories for swaroopnadella.
#
# 👤 Fetching data for user: belide
# No more repositories for belide.
#
# 👤 Fetching data for user: SriNandan33
# No more repositories for SriNandan33.
#
# 👤 Fetching data for user: sahitpj
# No more repositories for sahitpj.
#
# 👤 Fetching data for user: troublemagnet
# No more repositories for troublemagnet.
#
# 👤 Fetching data for user: SiddharthaBose30
# No more repositories for SiddharthaBose30.
#
# 👤 Fetching data for user: eyeamkd
# No more repositories for eyeamkd.
#
# 👤 Fetching data for user: fardeen9983
# No more repositories for fardeen9983.
#
# 👤 Fetching data for user: ShubhamVerma1811
# No more repositories for ShubhamVerma1811.
#
# 👤 Fetching data for user: OmGodse
# No more repositories for OmGodse.
#
# 👤 Fetching data for user: agarwalchaitanya
# No more repositories for agarwalchaitanya.
#
# 👤 Fetching data for user: gurramdhamodhar
# No more repositories for gurramdhamodhar.
#
# 👤 Fetching data for user: Dayitva
# No more repositories for Dayitva.
#
# 👤 Fetching data for user: nobelium
# No more repositories for nobelium.
#
# 👤 Fetching data for user: swainshashwat
# No more repositories for swainshashwat.
#
# 👤 Fetching data for user: bandirevanth1
# No more repositories for bandirevanth1.
#
# 👤 Fetching data for user: ashr81
# No more repositories for ashr81.
#
# 👤 Fetching data for user: Harshalshree
# No more repositories for Harshalshree.
#
# 👤 Fetching data for user: vamsitallapudi
# No more repositories for vamsitallapudi.
#
# 👤 Fetching data for user: Prathamkrishna
# No more repositories for Prathamkrishna.
#
# 👤 Fetching data for user: KORLA2
# No more repositories for KORLA2.
#
# 👤 Fetching data for user: AkashGutha
# No more repositories for AkashGutha.
#
# 👤 Fetching data for user: adhilcodes
# No more repositories for adhilcodes.
#
# 👤 Fetching data for user: CaptAlpha
# No more repositories for CaptAlpha.
#
# 👤 Fetching data for user: harshapathuri86
# No more repositories for harshapathuri86.
#
# 👤 Fetching data for user: nisabmohd
# No more repositories for nisabmohd.
#
# 👤 Fetching data for user: ReddyDivya
# No more repositories for ReddyDivya.
#
# 👤 Fetching data for user: mohdafzal21
# No more repositories for mohdafzal21.
#
# 👤 Fetching data for user: dixitgarg059
# No more repositories for dixitgarg059.
#
# 👤 Fetching data for user: Koorimikiran369
# No more repositories for Koorimikiran369.
#
# 👤 Fetching data for user: shivajivarma
# No more repositories for shivajivarma.
#
# 👤 Fetching data for user: raghurama123
# No more repositories for raghurama123.
#
# 👤 Fetching data for user: bvsatyaram
# No more repositories for bvsatyaram.
#
# 👤 Fetching data for user: sumanthd17
# No more repositories for sumanthd17.
#
# 👤 Fetching data for user: Naaman-Saif
# No more repositories for Naaman-Saif.
#
# 👤 Fetching data for user: Faizan2228
# No more repositories for Faizan2228.
#
# 👤 Fetching data for user: ashfaqnisar
# No more repositories for ashfaqnisar.
#
# 👤 Fetching data for user: piyushchauhan
# No more repositories for piyushchauhan.
#
# 👤 Fetching data for user: DilipItAcademy
# No more repositories for DilipItAcademy.
#
# 👤 Fetching data for user: theshivamlko
# No more repositories for theshivamlko.
#
# 👤 Fetching data for user: kulbirsaini
# No more repositories for kulbirsaini.
#
# 👤 Fetching data for user: DivyaKrishnani
# No more repositories for DivyaKrishnani.
#
# 👤 Fetching data for user: chintanrparmar
# No more repositories for chintanrparmar.
#
# 👤 Fetching data for user: mohan1998g
# No more repositories for mohan1998g.
#
# 👤 Fetching data for user: PawanAIT
# No more repositories for PawanAIT.
#
# 👤 Fetching data for user: sirreajohn
# No more repositories for sirreajohn.
#
# 👤 Fetching data for user: prashantkatiyar9777
# No more repositories for prashantkatiyar9777.
#
# 👤 Fetching data for user: neo-fetch
# No more repositories for neo-fetch.
#
# 👤 Fetching data for user: aaryan610
# No more repositories for aaryan610.
#
# 👤 Fetching data for user: bagwanpankaj
# No more repositories for bagwanpankaj.
#
# 👤 Fetching data for user: sanjay-sol
# No more repositories for sanjay-sol.
#
# 👤 Fetching data for user: SP9144
# No more repositories for SP9144.
#
# 👤 Fetching data for user: naveenjujaray
# No more repositories for naveenjujaray.
#
# 👤 Fetching data for user: devalab
# No more repositories for devalab.
#
# 👤 Fetching data for user: AnirG
# No more repositories for AnirG.
#
# 👤 Fetching data for user: RaghavSekhri
# No more repositories for RaghavSekhri.
#
# 👤 Fetching data for user: ktk53x
# No more repositories for ktk53x.
#
# 👤 Fetching data for user: gargroh
# No more repositories for gargroh.
#
# 👤 Fetching data for user: tarunguptaraja
# No more repositories for tarunguptaraja.
#
# 👤 Fetching data for user: avannaldas
# No more repositories for avannaldas.
#
# 👤 Fetching data for user: Megha-Bose
# No more repositories for Megha-Bose.
#
# 👤 Fetching data for user: ctrl-gaurav
# No more repositories for ctrl-gaurav.
#
# 👤 Fetching data for user: AmoghTiwari
# No more repositories for AmoghTiwari.
#
# 👤 Fetching data for user: AnushaNathRoy
# No more repositories for AnushaNathRoy.
#
# 👤 Fetching data for user: Rameshkumarpolavarapu
# No more repositories for Rameshkumarpolavarapu.
# 📊 Processing page 6 with 4 users found...
#
# 👤 Fetching data for user: Rahmath-001
# No more repositories for Rahmath-001.
#
# 👤 Fetching data for user: madhu314
# No more repositories for madhu314.
#
# 👤 Fetching data for user: bytesByHarsh
# No more repositories for bytesByHarsh.
#
# 👤 Fetching data for user: prateekkumarweb
# No more repositories for prateekkumarweb.
#
# 💾 Creating CSV files for 504 users and 36178 repositories...
# 📝 Generating README.md...
#
# ✅ Analysis complete! Check users.csv, repositories.csv, and README.md in /content directory.

# %%
#more cleaned users.csv
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Clean the company names
users_df['company'] = users_df['company'].str.strip()  # Trim whitespace
users_df['company'] = users_df['company'].str.lstrip('@')  # Strip leading '@'
users_df['company'] = users_df['company'].str.upper()  # Convert to uppercase

# Save the cleaned DataFrame back to users.csv
users_df.to_csv('users.csv', index=False)

print("Company names cleaned and saved to users.csv.")
# Out:
# Company names cleaned and saved to users.csv.

# %%
#repositories.csv
import requests
import csv

# Replace with your personal access token
GITHUB_TOKEN = 'GITHUB_TOKEN'
HEADERS = {'Authorization': f'token {GITHUB_TOKEN}'}
BASE_URL = 'https://api.github.com'

def read_users_from_csv(file_path):
    users = []
    with open(file_path, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            users.append(row['login'])
    return users

def get_repositories(username):
    repos = []
    page = 1
    while True:
        response = requests.get(f'{BASE_URL}/users/{username}/repos',
                                headers=HEADERS,
                                params={'sort': 'pushed', 'direction': 'desc', 'per_page': 100, 'page': page})
        data = response.json()

        if not data or len(repos) >= 500:
            break

        for repo in data:
            repos.append({
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo.get('license') else None  # Safely fetch license key
            })

        page += 1

    return repos[:500]  # Return up to 500 repos

def main():
    users = read_users_from_csv('users.csv')
    all_repos = []

    for user in users:
        repos = get_repositories(user)
        for repo in repos:
            all_repos.append({
                'login': user,
                **repo
            })

    # Write to CSV
    with open('repositories.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['login', 'full_name', 'created_at',
                      'stargazers_count', 'watchers_count',
                      'language', 'has_projects',
                      'has_wiki', 'license_name']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for repo in all_repos:
            writer.writerow(repo)

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9c37080e4787> in <cell line: 69>()
#      68
#      69 if __name__ == '__main__':
# ---> 70     main()
#
# <ipython-input-26-9c37080e4787> in main()
#      49
#      50     for user in users:
# ---> 51         repos = get_repositories(user)
#      52         for repo in repos:
#      53             all_repos.append({
#
# <ipython-input-26-9c37080e4787> in get_repositories(username)
#      30         for repo in data:
#      31             repos.append({
# ---> 32                 'full_name': repo['full_name'],
#      33                 'created_at': repo['created_at'],
#      34                 'stargazers_count': repo['stargazers_count'],
#
# TypeError: string indices must be integers

# %%
import pandas as pd
import statsmodels.api as sm

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna()]

# Calculate the length of the bio in words
#users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()

# The error was here: users_with_bio was used instead of users_with_bios
users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))


# Prepare the data for regression
X = users_with_bios['bio_word_count']  # Independent variable
y = users_with_bios['followers']        # Dependent variable

# Add a constant to the independent variable for the regression
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the regression slope (coefficient for bio_word_count)
slope = model.params['bio_word_count']

# Print the slope rounded to three decimal places
print(f'Regression slope of followers on bio word count: {slope:.3f}')
# Out:
# Regression slope of followers on bio word count: 8.393
# <ipython-input-27-85495eff9be2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))

# %%
#Q1
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Sort by followers and get top 5
top_users = users_df.sort_values(by='followers', ascending=False).head(5)

# Extract logins
top_logins = top_users['login'].tolist()
result = ', '.join(top_logins)

print(result)
# Out:
# iam-veeramalla, in28minutes, stacksimplify, thenaveensaggam, MadhavBahl

# %%
#Q2
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Convert created_at to datetime
users_df['created_at'] = pd.to_datetime(users_df['created_at'])

# Sort by created_at and get the earliest 5 users
earliest_users = users_df.sort_values(by='created_at').head(5)

# Extract logins
earliest_logins = earliest_users['login'].tolist()
result = ', '.join(earliest_logins)

print(result)
# Out:
# shabda, sitaramc, bagwanpankaj, srikanthlogic, kulbirsaini

# %%
#Q3
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Filter out missing license names
repositories_df = repositories_df[repositories_df['license_name'].notna()]

# Count occurrences of each license
license_counts = repositories_df['license_name'].value_counts()

# Get the top 3 licenses
top_licenses = license_counts.head(3).index.tolist()

# Join the license names in order
result = ', '.join(top_licenses)

print(result)
# Out:
# mit, apache-2.0, other

# %%
#Q4
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Count occurrences of each company
company_counts = users_df['company'].value_counts()

# Get the company with the highest count
most_common_company = company_counts.idxmax()
most_common_count = company_counts.max()

print(f"The majority of developers work at: {most_common_company} with {most_common_count} developers.")
# Out:
# The majority of developers work at: MICROSOFT with 17 developers.

# %%
#Q5
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Count occurrences of each programming language, ignoring missing values
language_counts = repositories_df['language'].value_counts()

# Get the most popular programming language
most_popular_language = language_counts.idxmax()
most_popular_count = language_counts.max()

print(f"The most popular programming language is: {most_popular_language} with {most_popular_count} repositories.")
# Out:
# The most popular programming language is: JavaScript with 5762 repositories.

# %%
#Q6
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')
repositories_df = pd.read_csv('repositories.csv')

# Convert created_at to datetime and filter users who joined after 2020
users_df['created_at'] = pd.to_datetime(users_df['created_at'])
recent_users = users_df[users_df['created_at'] > '2020-01-01']

# Get the logins of recent users
recent_user_logins = recent_users['login'].tolist()

# Filter repositories by these users
recent_repositories = repositories_df[repositories_df['login'].isin(recent_user_logins)]

# Count occurrences of each programming language
language_counts = recent_repositories['language'].value_counts()

# Get the second most popular programming language
second_most_popular_language = language_counts.nlargest(2).index[1]
second_most_popular_count = language_counts.nlargest(2).values[1]

print(f"The second most popular programming language among users who joined after 2020 is: {second_most_popular_language} with {second_most_popular_count} repositories.")
# Out:
# The second most popular programming language among users who joined after 2020 is: HTML with 777 repositories.

# %%
#Q7
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')

# Group by programming language and calculate the average stars
average_stars = repositories_df.groupby('language')['stargazers_count'].mean()

# Identify the language with the highest average stars
highest_average_language = average_stars.idxmax()
highest_average_value = average_stars.max()

print(f"The programming language with the highest average number of stars per repository is: {highest_average_language} with an average of {highest_average_value:.2f} stars.")
# Out:
# The programming language with the highest average number of stars per repository is: Perl with an average of 195.52 stars.

# %%
#Q8
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Calculate leader_strength
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# Sort by leader_strength and get the top 5
top_leaders = users_df.sort_values(by='leader_strength', ascending=False).head(5)

# Extract logins
top_logins = top_leaders['login'].tolist()
result = ', '.join(top_logins)

print(result)
# Out:
# in28minutes, iam-veeramalla, stacksimplify, ashokitschool, thenaveensaggam

# %%
#Q9
import pandas as pd

# Load the data
users_df = pd.read_csv('users.csv')

# Calculate the correlation between followers and public repositories
correlation = users_df['followers'].corr(users_df['public_repos'])

print(f"The correlation between the number of followers and the number of public repositories is: {correlation:.3f}")
# Out:
# The correlation between the number of followers and the number of public repositories is: 0.006

# %%
#Q10
import pandas as pd
import statsmodels.api as sm

# Load the data
users_df = pd.read_csv('users.csv')

# Define the independent variable (X) and dependent variable (Y)
X = users_df['public_repos']
Y = users_df['followers']

# Add a constant to the independent variable (for the intercept)
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(Y, X).fit()

# Get the summary of the regression results
summary = model.summary()

# Extract the coefficient for public_repos
additional_followers_per_repo = model.params['public_repos']

print(f"Regression Results:\n{summary}")
print(f"Estimated additional followers per additional public repository: {additional_followers_per_repo:.3f}")
# Out:
# Regression Results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              followers   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                   0.01983
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):              0.888
# Time:                        12:42:56   Log-Likelihood:                -4188.1
# No. Observations:                 504   AIC:                             8380.
# Df Residuals:                     502   BIC:                             8389.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          201.3644     56.618      3.557      0.000      90.127     312.602
# public_repos     0.0702      0.498      0.141      0.888      -0.909       1.050
# ==============================================================================
# Omnibus:                     1022.559   Durbin-Watson:                   0.265
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1063231.452
# Skew:                          14.632   Prob(JB):                         0.00
# Kurtosis:                     226.100   Cond. No.                         147.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Estimated additional followers per additional public repository: 0.070

# %%
#Q11
import pandas as pd

# Load the data
repositories_df = pd.read_csv('repositories.csv')


# Calculate the correlation directly
correlation = repositories_df['has_projects'].astype(int).corr(repositories_df['has_wiki'].astype(int))

print(f"The correlation between having projects enabled and having a wiki enabled is: {correlation:.3f}")
# Out:
# The correlation between having projects enabled and having a wiki enabled is: 0.171

# %%
#Q12
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate average following for both groups
average_hireable_following = hireable_users['following'].mean()
average_non_hireable_following = non_hireable_users['following'].mean()

# Calculate the difference
difference = average_hireable_following - average_non_hireable_following

# Print the result rounded to three decimal places
print(f'Difference in average following (hireable - non-hireable): {difference:.3f}')
# Out:
# Difference in average following (hireable - non-hireable): 33.270

# %%
#Q13
import pandas as pd
import statsmodels.api as sm

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna()]

# Calculate the length of the bio in words
#users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()

users_with_bios['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split()))


# Prepare the data for regression
X = users_with_bios['bio_word_count']  # Independent variable
y = users_with_bios['followers']        # Dependent variable

# Add a constant to the independent variable for the regression
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the regression slope (coefficient for bio_word_count)
slope = model.params['bio_word_count']

# Print the slope rounded to three decimal places
print(f'Regression slope of followers on bio word count: {slope:.3f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-187113772ce8> in <cell line: 14>()
#      12 #users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()
#      13
# ---> 14 users_with_bios['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split()))
#      15
#      16
#
# NameError: name 'users_with_bio' is not defined

# %%
#Q14
import pandas as pd

# Load the repositories data from the CSV file
repos_df = pd.read_csv('repositories.csv')

# Convert the created_at column to datetime
repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

# Filter for weekend days (Saturday: 5, Sunday: 6)
weekend_repos = repos_df[repos_df['created_at'].dt.dayofweek.isin([5, 6])]

# Count the number of repositories created by each user
top_users = weekend_repos['login'].value_counts().head(5)

# Get the top 5 users' logins in order
top_users_logins = ', '.join(top_users.index)

# Print the result
print(f'Top 5 users who created the most repositories on weekends: {top_users_logins}')
# Out:
# Top 5 users who created the most repositories on weekends: anjijava16, hemanth22, Shekharrajak, wahidKhan74, elevenpassin

# %%
#Q15
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Total number of users
total_users = len(users_df)

# Filter hireable and non-hireable users
hireable_users = users_df[users_df['hireable'] == True]
non_hireable_users = users_df[users_df['hireable'].isna() | (users_df['hireable'] == False)]

# Calculate the fraction of users with email in both groups
fraction_hireable_with_email = hireable_users['email'].notna().mean()
fraction_non_hireable_with_email = non_hireable_users['email'].notna().mean()

# Calculate the difference
difference = fraction_hireable_with_email - fraction_non_hireable_with_email

# Print the result rounded to three decimal places
print(f'Difference in fraction of users with email: {difference:.3f}')
# Out:
# Difference in fraction of users with email: 0.258

# %%
#Q16
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter out users without names
valid_users = users_df[users_df['name'].notna()]

# Extract surnames (last word in name)
valid_users['surname'] = valid_users['name'].str.strip().str.split().str[-1]

# Count occurrences of each surname
surname_counts = valid_users['surname'].value_counts()

# Find the most common surname(s)
max_count = surname_counts.max()
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort surnames alphabetically
most_common_surnames.sort()

# Count users with the most common surname
number_of_users = max_count

# Print results
most_common_surnames_str = ', '.join(most_common_surnames)
print(f'Most common surname(s): {most_common_surnames_str}')
print(f'Number of users with the most common surname: {number_of_users}')
# Out:
# Most common surname(s): Kumar
# Number of users with the most common surname: 12
# <ipython-input-24-dc0f22873520>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_users['surname'] = valid_users['name'].str.strip().str.split().str[-1]

# %% [markdown]
# Wrong Answers In Q11, 12, 15 > because In Original Files, Booleans are True/False . We have to upload Booleans as true/false in github repo. Run Scripts below and then upload resulting files to github.

# %%
repositories_df = pd.read_csv('repositories.csv')

# Check the data types and structure
print(repositories_df.head())

# Replace True/False with true/false
repositories_df['has_projects'] = repositories_df['has_projects'].replace({True: 'true', False: 'false'})
repositories_df['has_wiki'] = repositories_df['has_wiki'].replace({True: 'true', False: 'false'})

# Save the modified DataFrame back to the same CSV file
repositories_df.to_csv('repositories.csv', index=False)

# Check the data types and structure
print(repositories_df.head())

print("Updated CSV file saved successfully.")
# Out:
#          login                           full_name            created_at  \
# 0  krishnaik06  krishnaik06/Polars-GPU-Engine-Demo  2024-10-28T08:42:45Z
# 1  krishnaik06  krishnaik06/Transformers-Materials  2024-10-19T15:43:30Z
# 2  krishnaik06              krishnaik06/ETLWeather  2024-10-15T10:45:09Z
# 3  krishnaik06                krishnaik06/datasets  2024-10-08T05:16:12Z
# 4  krishnaik06             krishnaik06/testdagshub  2024-10-01T16:57:42Z
#
#    stargazers_count  watchers_count          language  has_projects  has_wiki  \
# 0                 1               1  Jupyter Notebook          True      True
# 1                10              10               NaN          True      True
# 2                 9               9            Python          True      True
# 3                 3               3               NaN          True      True
# 4                 0               0               NaN          True      True
#
#   license_name
# 0      gpl-3.0
# 1      gpl-3.0
# 2      gpl-3.0
# 3      gpl-3.0
# 4          NaN
#          login                           full_name            created_at  \
# 0  krishnaik06  krishnaik06/Polars-GPU-Engine-Demo  2024-10-28T08:42:45Z
# 1  krishnaik06  krishnaik06/Transformers-Materials  2024-10-19T15:43:30Z
# 2  krishnaik06              krishnaik06/ETLWeather  2024-10-15T10:45:09Z
# 3  krishnaik06                krishnaik06/datasets  2024-10-08T05:16:12Z
# 4  krishnaik06             krishnaik06/testdagshub  2024-10-01T16:57:42Z
#
#    stargazers_count  watchers_count          language has_projects has_wiki  \
# 0                 1               1  Jupyter Notebook         true     true
# 1                10              10               NaN         true     true
# 2                 9               9            Python         true     true
# 3                 3               3               NaN         true     true
# 4                 0               0               NaN         true     true
#
#   license_name
# 0      gpl-3.0
# 1      gpl-3.0
# 2      gpl-3.0
# 3      gpl-3.0
# 4          NaN
# Updated CSV file saved successfully.

# %%
users_df = pd.read_csv('users.csv')

# Check the data types and structure
print(users_df.head())

# Replace True/False with true/false in the hireable column
users_df['hireable'] = users_df['hireable'].replace({True: 'true', False: 'false'})

# Save the modified DataFrame back to the same CSV file
users_df.to_csv('users.csv', index=False)

# Check the data types and structure
print(users_df.head())


print("Updated CSV file saved successfully.")
# Out:
#              login           name          company          location  \
# 0      krishnaik06   Krish C Naik    PANASONIC IIC         Bangalore
# 1  championswimmer    Arnav Gupta        JIOCINEMA  Bangalore, India
# 2    arpitbbhayani  Arpit Bhayani           DICEDB         Bangalore
# 3    manjunath5496    Manjunath.R  MYW3SCHOOLS.COM  Bangalore, India
# 4      tanaypratap   Tanay Pratap           INVACT  Bangalore, India
#
#                      email hireable  \
# 0    krishnaik06@gmail.com      NaN
# 1   dev@championswimmer.in     True
# 2                      NaN     True
# 3  manjunath5496@gmail.com      NaN
# 4      tanay.mit@gmail.com      NaN
#
#                                                  bio  public_repos  followers  \
# 0  Data Scientist with ML and Deep  Learning expe...           330      30906
# 1  Director of Engineering - @JioCinema ┃\r\nPast...           351       4661
# 2  Creator of @DiceDB • ex-Google Dataproc, ex-Am...           188       4557
# 3  "Science is not only a disciple of reason but,...          1563       4084
# 4         Founder & CEO @invact . Teacher @neogcamp             40       3029
#
#    following            created_at
# 0          0  2016-06-20T09:25:45Z
# 1         29  2012-01-13T07:41:40Z
# 2          3  2013-06-20T06:40:12Z
# 3       9313  2016-06-16T05:02:32Z
# 4          1  2014-12-17T05:15:06Z
#              login           name          company          location  \
# 0      krishnaik06   Krish C Naik    PANASONIC IIC         Bangalore
# 1  championswimmer    Arnav Gupta        JIOCINEMA  Bangalore, India
# 2    arpitbbhayani  Arpit Bhayani           DICEDB         Bangalore
# 3    manjunath5496    Manjunath.R  MYW3SCHOOLS.COM  Bangalore, India
# 4      tanaypratap   Tanay Pratap           INVACT  Bangalore, India
#
#                      email hireable  \
# 0    krishnaik06@gmail.com      NaN
# 1   dev@championswimmer.in     true
# 2                      NaN     true
# 3  manjunath5496@gmail.com      NaN
# 4      tanay.mit@gmail.com      NaN
#
#                                                  bio  public_repos  followers  \
# 0  Data Scientist with ML and Deep  Learning expe...           330      30906
# 1  Director of Engineering - @JioCinema ┃\r\nPast...           351       4661
# 2  Creator of @DiceDB • ex-Google Dataproc, ex-Am...           188       4557
# 3  "Science is not only a disciple of reason but,...          1563       4084
# 4         Founder & CEO @invact . Teacher @neogcamp             40       3029
#
#    following            created_at
# 0          0  2016-06-20T09:25:45Z
# 1         29  2012-01-13T07:41:40Z
# 2          3  2013-06-20T06:40:12Z
# 3       9313  2016-06-16T05:02:32Z
# 4          1  2014-12-17T05:15:06Z
# Updated CSV file saved successfully.
